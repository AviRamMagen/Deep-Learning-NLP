# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.linear_model import LogisticRegressionCV
from sklearn.pipeline import make_pipeline
from sklearn import metrics
import eli5
from nltk import sent_tokenize
import nltk
from IPython.display import display
from IPython.core.display import HTML

# %%
categories = ['alt.atheism', 'soc.religion.christian',
              'comp.graphics', 'sci.med']
twenty_train = fetch_20newsgroups(
    subset='train',
    categories=categories,
    shuffle=True,
    random_state=42,
    remove=['headers', 'footers','quotes'],
)
twenty_test = fetch_20newsgroups(
    subset='test',
    categories=categories,
    shuffle=True,
    random_state=42,
    remove=['headers', 'footers','quotes'],
)

# %%
def return_first_x_sentences(text,x):
    sent_tokenize_list = sent_tokenize(text)
    first_x=sent_tokenize_list[:x]
    return '\n'.join(first_x)
SENT_NUM=2
twenty_train.data=map(lambda text: return_first_x_sentences(text,SENT_NUM),twenty_train.data)
twenty_test.data=map(lambda text: return_first_x_sentences(text,SENT_NUM),twenty_test.data)

# %%
def print_report(pipe):
    y_test = twenty_test.target
    y_pred = pipe.predict(twenty_test.data)
    report = metrics.classification_report(y_test, y_pred,
        target_names=twenty_test.target_names)
    print(report)
    print("accuracy: {:0.3f}".format(metrics.accuracy_score(y_test, y_pred)))
def get_mistake(pipe):
    y_test = twenty_test.target
    y_pred = pipe.predict(twenty_test.data)
    mistakes=[]
    for i in range(len(y_test)):
        if y_test[i]!=y_pred[i]:
            mistakes.append((twenty_test.data[i],twenty_test.target_names[y_pred[i]],twenty_test.target_names[y_test[i]]))
    return mistakes

# %%
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.linear_model import SGDClassifier

vec = TfidfVectorizer(stop_words='english', ngram_range=(1,2))
clf =LogisticRegressionCV()
pipe = make_pipeline(vec, clf)
pipe.fit(twenty_train.data, twenty_train.target)

print_report(pipe)
# Out:
#                         precision    recall  f1-score   support
#
#            alt.atheism       0.66      0.48      0.56       319
#          comp.graphics       0.83      0.84      0.84       389
#                sci.med       0.72      0.77      0.74       396
# soc.religion.christian       0.66      0.75      0.70       398
#
#            avg / total       0.72      0.72      0.72      1502
#
# accuracy: 0.721

# %%
mistakes_l=get_mistake(pipe)
for i in range(40):
    display(eli5.show_prediction(clf, mistakes_l[i][0], vec=vec,
                     target_names=twenty_test.target_names,targets=[mistakes_l[i][1],mistakes_l[i][2]]))
                     
    print
    print
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=soc.religion.christian
#
# </b>
#
#
#     (probability <b>0.595</b>, score <b>0.382</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.832
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 93.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.450
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">i </span><span style="background-color: hsl(0, 100.00%, 93.85%); opacity: 0.81" title="-0.123">heard</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(0, 100.00%, 96.65%); opacity: 0.81" title="-0.052">great</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.84%); opacity: 0.84" title="0.365">civil</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.26%); opacity: 0.83" title="0.237">war</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 88.83%); opacity: 0.83" title="0.289">story</span><span style="opacity: 0.80">...      a </span><span style="background-color: hsl(0, 100.00%, 83.37%); opacity: 0.86" title="-0.509">guy</span><span style="opacity: 0.80"> on the battlfield is </span><span style="background-color: hsl(0, 100.00%, 88.31%); opacity: 0.83" title="-0.308">shot</span><span style="opacity: 0.80">
# in the </span><span style="background-color: hsl(0, 100.00%, 86.63%); opacity: 0.84" title="-0.373">groin</span><span style="opacity: 0.80">,   the </span><span style="background-color: hsl(120, 100.00%, 92.34%); opacity: 0.82" title="0.168">bullet</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 81.60%); opacity: 0.87" title="-0.588">continues</span><span style="opacity: 0.80"> on it&#x27;s </span><span style="background-color: hsl(0, 100.00%, 94.43%); opacity: 0.81" title="-0.107">path</span><span style="opacity: 0.80">, and lodges in the
# abdomen of a </span><span style="background-color: hsl(120, 100.00%, 93.70%); opacity: 0.81" title="0.127">female</span><span style="opacity: 0.80"> spectator.
# lo and behold....
#
# as the </span><span style="background-color: hsl(120, 100.00%, 86.25%); opacity: 0.84" title="0.388">legend</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.68%); opacity: 0.82" title="0.223">goes</span><span style="opacity: 0.80">,   both </span><span style="background-color: hsl(120, 100.00%, 68.13%); opacity: 0.94" title="1.290">parents</span><span style="opacity: 0.80"> survived,  </span><span style="background-color: hsl(120, 100.00%, 74.89%); opacity: 0.90" title="0.917">married</span><span style="opacity: 0.80">,  and </span><span style="background-color: hsl(0, 100.00%, 85.50%); opacity: 0.85" title="-0.419">raised</span><span style="opacity: 0.80"> the </span><span style="background-color: hsl(0, 100.00%, 81.05%); opacity: 0.87" title="-0.614">child</span><span style="opacity: 0.80">.</span>
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=sci.med
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-7.956</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 95.06%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.951
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -7.005
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">i </span><span style="background-color: hsl(0, 100.00%, 86.32%); opacity: 0.84" title="-0.385">heard</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(120, 100.00%, 91.35%); opacity: 0.82" title="0.200">great</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 75.07%); opacity: 0.90" title="-0.908">civil</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-1.785">war</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 83.54%); opacity: 0.86" title="-0.502">story</span><span style="opacity: 0.80">...      a </span><span style="background-color: hsl(0, 100.00%, 96.36%); opacity: 0.81" title="-0.058">guy</span><span style="opacity: 0.80"> on the battlfield is </span><span style="background-color: hsl(120, 100.00%, 79.92%); opacity: 0.87" title="0.667">shot</span><span style="opacity: 0.80">
# in the </span><span style="background-color: hsl(120, 100.00%, 78.42%); opacity: 0.88" title="0.739">groin</span><span style="opacity: 0.80">,   the </span><span style="background-color: hsl(0, 100.00%, 93.79%); opacity: 0.81" title="-0.125">bullet</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.30%); opacity: 0.83" title="-0.271">continues</span><span style="opacity: 0.80"> on it&#x27;s </span><span style="background-color: hsl(0, 100.00%, 9
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=soc.religion.christian
#
# </b>
#
#
#     (probability <b>0.955</b>, score <b>-2.028</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 95.11%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.579
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 90.69%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.450
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">
# if you </span><span style="background-color: hsl(0, 100.00%, 88.75%); opacity: 0.83" title="-0.239">read</span><span style="opacity: 0.80"> the last </span><span style="background-color: hsl(120, 100.00%, 92.21%); opacity: 0.82" title="0.142">couple</span><span style="opacity: 0.80"> of </span><span style="background-color: hsl(120, 100.00%, 74.90%); opacity: 0.90" title="0.752">books</span><span style="opacity: 0.80"> in the </span><span style="background-color: hsl(0, 100.00%, 82.55%); opacity: 0.86" title="-0.448">series</span><span style="opacity: 0.80"> closely (well, #3 and #4
# at least), there are at least two </span><span style="background-color: hsl(0, 100.00%, 65.72%); opacity: 0.96" title="-1.175">points</span><span style="opacity: 0.80"> at which the </span><span style="background-color: hsl(120, 100.00%, 87.76%); opacity: 0.84" title="0.270">real</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.43%); opacity: 0.83" title="0.219">question</span><span style="opacity: 0.80"> is
# </span><span style="background-color: hsl(0, 100.00%, 81.08%); opacity: 0.87" title="-0.503">implied</span><span style="opacity: 0.80">.
# </span><span style="background-color: hsl(120, 100.00%, 79.69%); opacity: 0.88" title="0.556">conversations</span><span style="opacity: 0.80"> proceed much </span><span style="background-color: hsl(120, 100.00%, 77.74%); opacity: 0.89" title="0.634">like</span><span style="opacity: 0.80">:
#
# </span><span style="background-color: hsl(0, 100.00%, 90.22%); opacity: 0.83" title="-0.196">zaphod</span><span style="opacity: 0.80">: what *is* the </span><span style="background-color: hsl(0, 100.00%, 96.34%); opacity: 0.81" title="-0.048">ultimate</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.43%); opacity: 0.83" title="0.219">question</span><span style="opacity: 0.80">, i </span><span style="background-color: hsl(0, 100.00%, 74.68%); opacity: 0.90" title="-0.762">wonder</span><span style="opacity: 0.80">?</span>
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=comp.graphics
#
# </b>
#
#
#     (probability <b>0.041</b>, score <b>-5.286</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 93.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.960
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -4.326
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">
# if you </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-1.465">read</span><span style="opacity: 0.80"> the last </span><span style="background-color: hsl(120, 100.00%, 98.73%); opacity: 0.80" title="0.011">couple</span><span style="opacity: 0.80"> of </span><span style="background-color: hsl(0, 100.00%, 75.66%); opacity: 0.90" title="-0.720">books</span><span style="opacity: 0.80"> in the </span><span style="background-color: hsl(120, 100.00%, 85.14%); opacity: 0.85" title="0.356">series</span><span style="opacity: 0.80"> closely (well, #3 and #4
# at least), there are at least two </span><span style="background-color: hsl(120, 100.00%, 66.22%); opacity: 0.96" title="1.150">points</span><span style="opacity: 0.80"> at which the </span><span style="background-color: hsl(0, 100.00%, 92.10%); opacity: 0.82" title="-0.144">real</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 77.66%); opacity: 0.89" title="-0.637">question</span><span style="opacity: 0.80"> is
# </span><span style="background-color: hsl(0, 100.00%, 85.88%); opacity: 0.85" title="-0.331">implied</span><span style="opacity: 0.80">.
# </span><span style="background-color: hsl(0, 100.00%, 89.21%); opacity: 0.83" title="-0.225">conversations</span><span style="opacity: 0.80"> proceed much </span><span style="background-color: hsl(0, 100.00%, 70.34%); opacity: 0.93" title="-0.955">like</span><span style="opacity: 0.80">:
#
# </span><span style="background-color: hsl(120, 100.00%, 87.09%); opacity: 0.84" title="0.291">zaphod</span><span style="opacity: 0.80">: what *is* the </span><span style="background-color: hsl(120, 100.00%, 93.44%); opacity: 0.82" title="0.111">ultimate</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 77.66%); opacity: 0.89" title="-0.637">question</span><span style="opacity: 0.80">, i </span><span style="background-color: hsl(0, 100.00%, 66.65%); opacity: 0.95" title="-1.130">wonde
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=sci.med
#
# </b>
#
#
#     (probability <b>0.948</b>, score <b>0.190</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.52%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.140
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 92.54%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.951
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">[this is swf in another indirect </span><span style="background-color: hsl(0, 100.00%, 83.61%); opacity: 0.86" title="-0.619">post</span><span style="opacity: 0.80"> via </span><span style="background-color: hsl(0, 100.00%, 74.79%); opacity: 0.90" title="-1.146">dan</span><span style="opacity: 0.80">].
# predicitions
# if you
# have some
# many </span><span style="background-color: hsl(0, 100.00%, 91.05%); opacity: 0.82" title="-0.261">types</span><span style="opacity: 0.80"> of
# </span><span style="background-color: hsl(120, 100.00%, 69.58%); opacity: 0.94" title="1.498">happen</span><span style="opacity: 0.80"> again
# may </span><span style="background-color: hsl(0, 100.00%, 95.27%); opacity: 0.81" title="-0.105">predict</span><span style="opacity: 0.80">
# </span><span style="background-color: hsl(120, 100.00%, 63.31%); opacity: 0.98" title="1.958">reaction</span><span style="opacity: 0.80">
#
# there are several </span><span style="background-color: hsl(0, 100.00%, 92.97%); opacity: 0.82" title="-0.185">problems</span><span style="opacity: 0.80"> here.</span>
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=alt.atheism
#
# </b>
#
#
#     (probability <b>0.011</b>, score <b>-5.026</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 91.52%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.140
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.886
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">[this is swf in another indirect </span><span style="background-color: hsl(0, 100.00%, 94.35%); opacity: 0.81" title="-0.135">post</span><span style="opacity: 0.80"> via </span><span style="background-color: hsl(120, 100.00%, 61.89%); opacity: 0.99" title="2.067">dan</span><span style="opacity: 0.80">].
# predicitions
# if you
# have some
# many </span><span style="background-color: hsl(0, 100.00%, 89.56%); opacity: 0.83" title="-0.325">types</span><span style="opacity: 0.80"> of
# </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-2.215">happen</span><span style="opacity: 0.80"> again
# may </span><span style="background-color: hsl(0, 100.00%, 90.52%); opacity: 0.83" title="-0.283">predict</span><span style="opacity: 0.80">
# </span><span style="background-color: hsl(0, 100.00%, 71.13%); opacity: 0.93" title="-1.390">reaction</span><span style="opacity: 0.80">
#
# there are several </span><span style="background-color: hsl(0, 100.00%, 68.08%); opacity: 0.94" title="-1.604">problems</span><span style="opacity: 0.80"> here.</span>
#     </p>
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=soc.religion.christian
#
# </b>
#
#
#     (probability <b>0.573</b>, score <b>-1.492</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.043
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.450
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">
# </span><span style="background-color: hsl(0, 100.00%, 86.23%); opacity: 0.84" title="-0.383">knowing</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 67.10%); opacity: 0.95" title="-1.328">keith</span><span style="opacity: 0.80">, i </span><span style="background-color: hsl(120, 100.00%, 67.41%); opacity: 0.95" title="1.310">expect</span><span style="opacity: 0.80"> he&#x27;</span><span style="background-color: hsl(0, 100.00%, 84.61%); opacity: 0.85" title="-0.449">ll</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 66.90%); opacity: 0.95" title="1.340">bring</span><span style="opacity: 0.80"> the </span><span style="background-color: hsl(120, 100.00%, 77.47%); opacity: 0.89" title="0.773">leather</span><span style="opacity: 0.80"> accessories.
# </span><span style="background-color: hsl(0, 100.00%, 63.15%); opacity: 0.98" title="-1.561">better</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.64%); opacity: 0.83" title="0.255">oil</span><span style="opacity: 0.80"> it well.</span>
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=alt.atheism
#
# </b>
#
#
#     (probability <b>0.402</b>, score <b>-1.913</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.13%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.772
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 83.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.140
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">
# </span><span style="background-color: hsl(120, 100.00%, 69.18%); opacity: 0.94" title="1.209">knowing</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.756">keith</span><span style="opacity: 0.80">, i </span><span style="background-color: hsl(120, 100.00%, 95.21%); opacity: 0.81" title="0.085">expect</span><span style="opacity: 0.80"> he&#x27;</span><span style="background-color: hsl(0, 100.00%, 65.39%); opacity: 0.96" title="-1.428">ll</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 73.83%); opacity: 0.91" title="-0.957">bring</span><span style="opacity: 0.80"> the </span><span style="background-color: hsl(0, 100.00%, 83.92%); opacity: 0.85" title="-0.478">leather</span><span style="opacity: 0.80"> accessories.
# </span><span style="background-color: hsl(0, 100.00%, 87.72%); opacity: 0.84" title="-0.325">better</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 80.38%); opacity: 0.87" title="-0.635">oil</span><span style="opacity: 0.80"> it well.</span>
#     </p>
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=comp.graphics
#
# </b>
#
#
#     (probability <b>0.571</b>, score <b>-0.998</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.038
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 82.27%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.960
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">as </span><span style="background-color: hsl(120, 100.00%, 75.86%); opacity: 0.90" title="0.688">requested</span><span style="opacity: 0.80">, here are some </span><span style="background-color: hsl(0, 100.00%, 66.42%); opacity: 0.96" title="-1.102">addresses</span><span style="opacity: 0.80"> of </span><span style="background-color: hsl(0, 100.00%, 93.81%); opacity: 0.81" title="-0.098">sources</span><span style="opacity: 0.80"> of </span><span style="background-color: hsl(120, 100.00%, 87.33%); opacity: 0.84" title="0.274">bizarre</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 62.96%); opacity: 0.98" title="-1.268">religious</span><span style="opacity: 0.80"> satire
# and </span><span style="background-color: hsl(0, 100.00%, 86.09%); opacity: 0.84" title="-0.313">commentary</span><span style="opacity: 0.80">...  </span><span style="background-color: hsl(120, 100.00%, 74.50%); opacity: 0.91" title="0.744">plus</span><span style="opacity: 0.80"> some bijou </span><span style="background-color: hsl(0, 100.00%, 90.24%); opacity: 0.83" title="-0.189">book</span><span style="opacity: 0.80"> reviewettes.
# ---
#
# loompanics </span><span style="background-color: hsl(0, 100.00%, 93.40%); opacity: 0.82" title="-0.108">unlimited</span><span style="opacity: 0.80">
# </span><span style="background-color: hsl(0, 100.00%, 83.49%); opacity: 0.86" title="-0.400">po</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 80.58%); opacity: 0.87" title="0.504">box</span><span style="opacity: 0.80"> 1197
# </span><span style="background-color: hsl(120, 100.00%, 63.74%); opacity: 0.97" title="1.230">port</span><span style="opacity: 0.80"> townsend, wa 98368.</span>
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=alt.atheism
#
# </b>
#
#
#     (probability <b>0.385</b>, score <b>-1.505</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 90.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.365
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.140
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">as </span><span style="background-color: hsl(120, 100.00%, 80.32%); opacity: 0.87" title="0.514">requested</span><span style="opacity: 0.80">, here are some </span><span style="background-color: hsl(0, 100.00%, 71.86%); opacity: 0.92" title="-0.856">addresses</span><span style="opacity: 0.80"> of </span><span style="background-color: hsl(0, 100.00%, 72.80%); opacity: 0.92" title="-0.816">sources</span><span style="opacity: 0.80"> of </span><span style="background-color: hsl(0, 100.00%, 89.61%); opacity: 0.83" title="-0.206">bizarre</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.415">religious</span><span style="opacity: 0.80"> satire
# and </span><span style="background-color: hsl(0, 100.00%, 90.52%); opacity: 0.83" title="-0.181">commentary</span><span style="opacity: 0.80">...  </span><span style="background-color: hsl(0, 100.00%, 75.67%); opacity: 0.90" title="-0.696">plus</span><span style="opacity: 0.80"> some bijou </span><span style="background-color: hsl(0, 100.00%, 95.38%); opacity: 0.81" title="-0.065">book</span><span style="opacity: 0.80"> reviewettes.
# ---
#
# loompanics </span><span style="background-color: hsl(120, 100.00%, 80.28%); opacity: 0.87" title="0.515">unlimited</span><span style="opacity: 0.80">
# </span><span style="background-color: hsl(120, 100.00%, 72.98%); opacity: 0.91" title="0.808">po</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 86.82%); opacity: 0.84" title="-0.290">box</span><span style="opacity: 0.80"> 1197
# </span><span style="background-color: hsl(0, 100.00%, 80.50%); opacity: 0.87" title="-0.507">port</span><span style="opacity: 0.80"> townsend, wa 98368.</span>
#     </p>
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=soc.religion.christian
#
# </b>
#
#
#     (probability <b>0.633</b>, score <b>-2.483</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 88.81%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.033
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.450
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">the </span><span style="background-color: hsl(120, 100.00%, 76.79%); opacity: 0.89" title="0.877">following</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 79.76%); opacity: 0.88" title="-0.721">article</span><span style="opacity: 0.80"> by columnist </span><span style="background-color: hsl(120, 100.00%, 84.93%); opacity: 0.85" title="0.473">mike</span><span style="opacity: 0.80"> royko is his humorous </span><span style="background-color: hsl(120, 100.00%, 82.75%); opacity: 0.86" title="0.574">commentary</span><span style="opacity: 0.80">
# on some of the </span><span style="background-color: hsl(0, 100.00%, 84.71%); opacity: 0.85" title="-0.483">public</span><span style="opacity: 0.80">&#x27;s </span><span style="background-color: hsl(0, 100.00%, 97.39%); opacity: 0.80" title="-0.039">perception</span><span style="opacity: 0.80"> of </span><span style="background-color: hsl(0, 100.00%, 90.93%); opacity: 0.82" title="-0.229">doctors</span><span style="opacity: 0.80"> and their salaries.
# i </span><span style="background-color: hsl(0, 100.00%, 97.58%); opacity: 0.80" title="-0.035">hope</span><span style="opacity: 0.80"> some of you will find it as </span><span style="background-color: hsl(120, 100.00%, 82.17%); opacity: 0.86" title="0.602">amusing</span><span style="opacity: 0.80"> as i </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-1.908">did</span><span style="opacity: 0.80">.</span>
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=sci.med
#
# </b>
#
#
#     (probability <b>0.287</b>, score <b>-3.321</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 89.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.951
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.370
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">the </span><span style="background-color: hsl(0, 100.00%, 76.32%); opacity: 0.89" title="-0.902">following</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 85.96%); opacity: 0.84" title="-0.428">article</span><span style="opacity: 0.80"> by columnist </span><span style="background-color: hsl(0, 100.00%, 81.94%); opacity: 0.86" title="-0.613">mike</span><span style="opacity: 0.80"> royko is his humorous </span><span style="background-color: hsl(0, 100.00%, 93.34%); opacity: 0.82" title="-0.147">commentary</span><span style="opacity: 0.80">
# on some of the </span><span style="background-color: hsl(0, 100.00%, 67.40%); opacity: 0.95" title="-1.424">public</span><span style="opacity: 0.80">&#x27;s </span><span style="background-color: hsl(0, 100.00%, 97.21%); opacity: 0.80" title="-0.043">perception</span><span style="opacity: 0.80"> of </span><span style="background-color: hsl(120, 100.00%, 68.37%); opacity: 0.94" title="1.364">doctors</span><span style="opacity: 0.80"> and their salaries.
# i </span><span style="background-color: hsl(0, 100.00%, 88.98%); opacity: 0.83" title="-0.302">hope</span><span style="opacity: 0.80"> some of you will find it as </span><span style="background-color: hsl(0, 100.00%, 88.41%); opacity: 0.83" title="-0.325">amusing</span><span style="opacity: 0.80"> as i </span><span style="background-color: hsl(120, 100.00%, 93.79%); opacity: 0.81" title="0.133">did</span><span style="opacity: 0.80">.</span>
#     </p>
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=alt.atheism
#
# </b>
#
#
#     (probability <b>0.649</b>, score <b>0.175</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.315
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 92.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.140
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">
#
# </span><span style="background-color: hsl(120, 100.00%, 77.34%); opacity: 0.89" title="1.559">oh</span><span style="opacity: 0.80">.
# </span><span style="background-color: hsl(0, 100.00%, 80.30%); opacity: 0.87" title="-1.277">ok</span><span style="opacity: 0.80"> then, </span><span style="background-color: hsl(120, 100.00%, 69.61%); opacity: 0.94" title="2.372">sorry</span><span style="opacity: 0.80"> for </span><span style="background-color: hsl(0, 100.00%, 79.63%); opacity: 0.88" title="-1.340">misunderstanding</span><span style="opacity: 0.80">.</span>
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=comp.graphics
#
# </b>
#
#
#     (probability <b>0.003</b>, score <b>-5.917</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 93.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.960
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -4.957
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">
#
# </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-3.513">oh</span><span style="opacity: 0.80">.
# </span><span style="background-color: hsl(0, 100.00%, 98.05%); opacity: 0.80" title="-0.047">ok</span><span style="opacity: 0.80"> then, </span><span style="background-color: hsl(0, 100.00%, 96.56%); opacity: 0.81" title="-0.105">sorry</span><span style="opacity: 0.80"> for </span><span style="background-color: hsl(0, 100.00%, 80.14%); opacity: 0.87" title="-1.292">misunderstanding</span><span style="opacity: 0.80">.</span>
#     </p>
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
# ...
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=alt.atheism
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-9.514</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 95.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.140
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -8.374
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">
#
#
# of </span><span style="background-color: hsl(120, 100.00%, 96.71%); opacity: 0.81" title="0.172">course</span><span style="opacity: 0.80"> not.
# i would </span><span style="background-color: hsl(0, 100.00%, 84.02%); opacity: 0.85" title="-1.646">think</span><span style="opacity: 0.80"> that would be </span><span style="background-color: hsl(0, 100.00%, 89.10%); opacity: 0.83" title="-0.952">great</span><span style="opacity: 0.80"> _fun_, not </span><span style="background-color: hsl(0, 100.00%, 90.86%); opacity: 0.82" title="-0.741">having</span><span style="opacity: 0.80"> ever
# </span><span style="background-color: hsl(0, 100.00%, 90.06%); opacity: 0.83" title="-0.835">felt</span><span style="opacity: 0.80"> the joy and </span><span style="background-color: hsl(0, 100.00%, 90.06%); opacity: 0.83" title="-0.835">peace</span><span style="opacity: 0.80"> the </span><span style="background-color: hsl(0, 100.00%, 73.99%); opacity: 0.91" title="-3.301">christians</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.90%); opacity: 0.81" title="-0.236">speak</span><span style="opacity: 0.80"> of with a longing gaze.</span>
#     </p>
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=comp.graphics
#
# </b>
#
#
#     (probability <b>0.912</b>, score <b>-1.951</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 94.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.960
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 94.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.991
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">perhaps it&#x27;s </span><span style="background-color: hsl(0, 100.00%, 90.14%); opacity: 0.83" title="-0.403">prophetic</span><span style="opacity: 0.80"> that the </span><span style="background-color: hsl(0, 100.00%, 84.95%); opacity: 0.85" title="-0.737">week</span><span style="opacity: 0.80"> &quot;where are they now?&quot;
# </span><span style="background-color: hsl(0, 100.00%, 86.84%); opacity: 0.84" title="-0.608">appears</span><span style="opacity: 0.80"> and
# i can </span><span style="background-color: hsl(0, 100.00%, 82.35%); opacity: 0.86" title="-0.925">claim</span><span style="opacity: 0.80"> to be a still-</span><span style="background-color: hsl(0, 100.00%, 85.78%); opacity: 0.85" title="-0.680">active</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 84.97%); opacity: 0.85" title="-0.735">old</span><span style="opacity: 0.80">-timer, my </span><span style="background-color: hsl(120, 100.00%, 95.33%); opacity: 0.81" title="0.138">news</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="2.977">software</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 79.73%); opacity: 0.88" title="-1.128">gets</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.66%); opacity: 0.82" title="0.317">bit</span><span style="opacity: 0.80">
# rot and ships </span><span style="background-color: hsl(0, 100.00%, 96.05%); opacity: 0.81" title="-0.109">outgoing</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 79.39%); opacity: 0.88" title="1.155">articles</span><span style="opacity: 0.80"> into a </span><span style="background-color: hsl(0, 100.00%, 94.50%); opacity: 0.81" title="-0.175">deep</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.83%); opacity: 0.81" title="-0.080">hole</span><span style="opacity: 0.80"> somewhere...</span>
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=alt.atheism
#
# </b>
#
#
#     (probability <b>0.002</b>, score <b>-8.019</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 94.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.140
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -6.879
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">perhaps it&#x27;s </span><span style="background-color: hsl(0, 100.00%, 87.78%); opacity: 0.84" title="-0.547">prophetic</span><span style="opacity: 0.80"> that the </span><span style="background-color: hsl(0, 100.00%, 76.65%); opacity: 0.89" title="-1.380">week</span><span style="opacity: 0.80"> &quot;where are they now?&quot;
# </span><span style="background-color: hsl(0, 100.00%, 87.82%); opacity: 0.84" title="-0.545">appears</span><span style="opacity: 0.80"> and
# i can </span><span style="background-color: hsl(120, 100.00%, 84.94%); opacity: 0.85" title="0.737">claim</span><span style="opacity: 0.80"> to be a still-</span><span style="background-color: hsl(0, 100.00%, 88.90%); opacity: 0.83" title="-0.477">active</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 85.16%); opacity: 0.85" title="-0.722">old</span><span style="opacity: 0.80">-timer, my </span><span style="background-color: hsl(0, 100.00%, 98.72%); opacity: 0.80" title="-0.022">news</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 72.51%); opacity: 0.92" title="-1.742">software</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 84.69%); opacity: 0.85" title="-0.755">gets</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 88.19%); opacity: 0.84" title="-0.521">bit</span><span style="opacity: 0.80">
# rot and ships </span><span style="background-color: hsl(120, 100.00%, 88.19%); opacity: 0.83" title="0.521">outgoing</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 86.36%); opacity: 0.84" title="-0.640">articles</span><span style="opacity: 0.80"> into a </span><span style="background-color: hsl(0, 100.00%, 86.61%); opacity: 0.84" title="-0.624">deep</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.80%); opacity: 0.81" title="-0.162">hole</span><span style="opacity: 0.80"> somewhere...</span>
#     </p>
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=soc.religion.christian
#
# </b>
#
#
#     (probability <b>0.870</b>, score <b>8.244</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +9.694
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 94.71%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.450
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">
#
# &quot;this is your </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="6.981">god</span><span style="opacity: 0.80">&quot; (from </span><span style="background-color: hsl(120, 100.00%, 76.18%); opacity: 0.90" title="3.329">john</span><span style="opacity: 0.80"> carpenter&#x27;s &quot;they </span><span style="background-color: hsl(0, 100.00%, 92.69%); opacity: 0.82" title="-0.616">live</span><span style="opacity: 0.80">,&quot; natch)</span>
#     </p>
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=alt.atheism
#
# </b>
#
#
#     (probability <b>0.130</b>, score <b>-1.739</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 97.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.599
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 95.53%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.140
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">
#
# &quot;this is your </span><span style="background-color: hsl(0, 100.00%, 89.18%); opacity: 0.83" title="-1.078">god</span><span style="opacity: 0.80">&quot; (from </span><span style="background-color: hsl(0, 100.00%, 95.80%); opacity: 0.81" title="-0.279">john</span><span style="opacity: 0.80"> carpenter&#x27;s &quot;they </span><span style="background-color: hsl(120, 100.00%, 91.54%); opacity: 0.82" title="0.759">live</span><span style="opacity: 0.80">,&quot; natch)</span>
#     </p>

# %%
eli5.show_prediction(clf, twenty_test.data[0], vec=vec,
                     target_names=twenty_test.target_names,
                     targets=['sci.med'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=sci.med
#
# </b>
#
#
#     (probability <b>0.989</b>, score <b>7.267</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +8.218
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 95.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.951
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">as i </span><span style="background-color: hsl(120, 100.00%, 80.81%); opacity: 0.87" title="1.057">recall</span><span style="opacity: 0.80"> from my bout with </span><span style="background-color: hsl(120, 100.00%, 62.11%); opacity: 0.99" title="2.794">kidney</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 62.11%); opacity: 0.99" title="2.794">stones</span><span style="opacity: 0.80">, there </span><span style="background-color: hsl(0, 100.00%, 94.55%); opacity: 0.81" title="-0.175">isn</span><span style="opacity: 0.80">&#x27;t any
# </span><span style="background-color: hsl(120, 100.00%, 78.81%); opacity: 0.88" title="1.218">medication</span><span style="opacity: 0.80"> that can do anything about them except relieve the </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="3.018">pain</span><span style="opacity: 0.80">.
# either they </span><span style="background-color: hsl(0, 100.00%, 78.84%); opacity: 0.88" title="-1.216">pass</span><span style="opacity: 0.80">, or they have to be </span><span style="background-color: hsl(0, 100.00%, 75.40%); opacity: 0.90" title="-1.507">broken</span><span style="opacity: 0.80"> up with </span><span style="background-color: hsl(120, 100.00%, 88.39%); opacity: 0.83" title="0.516">sound</span><span style="opacity: 0.80">, or they have
# to be </span><span style="background-color: hsl(120, 100.00%, 80.05%); opacity: 0.87" title="1.117">extracted</span><span style="opacity: 0.80"> surgically.</span>
#     </p>

# %%
eli5.show_weights(clf, vec=vec, top=20,
                  target_names=twenty_test.target_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=alt.atheism
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=comp.graphics
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=sci.med
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=soc.religion.christian
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.30%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +22.081
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         atheism
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.67%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +14.722
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         bobby
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.90%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +14.370
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         islam
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +12.898
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         atheists
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.02%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +12.647
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         religion
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +12.033
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         motto
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +11.385
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         deletion
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +10.247
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         freedom
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.76%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +10.099
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         objective
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +9.977
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         sorry wrong
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 89.85%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 7652 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 89.70%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 30837 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 89.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.187
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         jesus
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.314
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         doctor
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.533
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         like
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.642
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         believe
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.811
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         msg
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.819
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         christians
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.963
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; bo

# %%
sample=twenty_test.data[0]
sentences = nltk.sent_tokenize(sample)
tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sentences]
tagged_sentences = [nltk.pos_tag(sentence) for sentence in tokenized_sentences]
chunked_sentences = nltk.ne_chunk_sents(tagged_sentences, binary=True)


def extract_entity_names(t):
    entity_names = []
    print(t)
    if hasattr(t, 'node') and t.node:
        if t.node == 'NE':
            entity_names.append(' '.join([child[0] for child in t]))
        else:
            for child in t:
                entity_names.extend(extract_entity_names(child))
                
    return entity_names

entity_names = []
for tree in chunked_sentences:
    # Print results per sentence
    # print extract_entity_names(tree)
    
    entity_names.extend(extract_entity_names(tree))

# Print all entity names
#print entity_names

# Print unique entity names
print set(entity_names)
# Out:
# (S
#   As/IN
#   I/PRP
#   recall/VBP
#   from/IN
#   my/PRP$
#   bout/NN
#   with/IN
#   kidney/NN
#   stones/NNS
#   ,/,
#   there/EX
#   is/VBZ
#   n't/RB
#   any/DT
#   medication/NN
#   that/WDT
#   can/MD
#   do/VB
#   anything/NN
#   about/IN
#   them/PRP
#   except/IN
#   relieve/VBP
#   the/DT
#   pain/NN
#   ./.)
# (S
#   Either/DT
#   they/PRP
#   pass/VBP
#   ,/,
#   or/CC
#   they/PRP
#   have/VBP
#   to/TO
#   be/VB
#   broken/VBN
#   up/RP
#   with/IN
#   sound/NN
#   ,/,
#   or/CC
#   they/PRP
#   have/VBP
#   to/TO
#   be/VB
#   extracted/VBN
#   surgically/RB
#   ./.)
# set([])
